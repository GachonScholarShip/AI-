# %%
import pandas as pd

# 파일 로드 함수
def load_data(file_path):
    print(f"파일 로드 중: {file_path}")  # 파일 경로 출력
    if file_path.endswith('.xlsx') or file_path.endswith('.xls'):
        df = pd.read_excel(file_path)
    elif file_path.endswith('.csv'):
        df = pd.read_csv(file_path, encoding='utf-8')
    else:
        raise ValueError("지원하지 않는 파일 형식입니다. XLSX 또는 CSV 파일을 사용하세요.")

    print("데이터 로드 완료!")
    print(df.head())  # 데이터프레임 일부 출력
    return df

# 비전타워 강의실 필터링
def filter_visiontower(df):
    print("비전타워 강의실 필터링 중...")
    filtered_df = df[df['강의실'].str.contains('비전타워', na=False)]

    print(f"필터링된 강의 수: {len(filtered_df)}개")
    print(filtered_df.head())  # 필터링된 데이터 일부 출력
    return filtered_df[['교과목명', '강의시간', '강의실']]

# 실행 함수
def main(file_path, output_path):
    df = load_data(file_path)
    visiontower_df = filter_visiontower(df)

    print(f"저장 중: {output_path}")
    visiontower_df.to_csv(output_path, index=False, encoding='utf-8')
    print(f"필터링 완료! 결과 저장: {output_path}")

# 실행 예시
main('시간표_및_강의계획서_최종통합.xlsx', '비전타워_강의목록.csv')
# Out:
# 파일 로드 중: 시간표_및_강의계획서_최종통합.xlsx
# 데이터 로드 완료!
#   No      학수번호                          교과목명 관련영상          영역  이수      학점  \
# 0  1  14736002                       일본의이해     없음  [계교]인문사회과학  계교  3(3/0)
# 1  2  15503001  한국어학의 이해 (Flipped Learning)    없음  [계교]인문사회과학  계교  3(2/1)
# 2  3  15503002  한국어학의 이해 (Flipped Learning)    없음  [계교]인문사회과학  계교  3(2/1)
# 3  4  15504001               문화콘텐츠 분석과 상상력     없음  [계교]인문사회과학  계교  3(2/1)
# 4  5  15504002               문화콘텐츠 분석과 상상력     없음  [계교]인문사회과학  계교  3(2/1)
#
#       개설조직  담당교수        강의시간      강의실  정원
# 0  AI인문대학1   이수향  수3 ,수4 ,금3  가천관-315  60
# 1  AI인문대학1  정한데로  월7 ,수5 ,수6  가천관-413  40
# 2  AI인문대학1  정한데로  월8 ,수7 ,수8  가천관-413  40
# 3  AI인문대학1   김진규  월3 ,월4 ,수4  가천관-414  40
# 4  AI인문대학1   김진규  화3 ,화4 ,수3  가천관-414  40
# 비전타워 강의실 필터링 중...
# 필터링된 강의 수: 580개
#     No      학수번호       교과목명 관련영상        영역  이수      학점     개설조직 담당교수    강의시간  \
# 39  40  13549014  인문사회글쓰기     없음  [기초]의사소통  교필  2(2/0)  AI인문대학1  허재홍  목5 ,목6
# 40  41  13549041  인문사회글쓰기     없음  [기초]의사소통  교필  2(2/0)  AI인문대학1  변정민  목5 ,목6
# 41  42  13549042  인문사회글쓰기     없음  [기초]의사소통  교필  2(2/0)  AI인문대학1  최정혜  목5 ,목6
# 42  43  13549043  인문사회글쓰기     없음  [기초]의사소통  교필  2(2/0)  AI인문대학1  정우진  목3 ,목4
# 43  44  13549044  인문사회글쓰기     없음  [기초]의사소통  교필  2(2/0)  AI인문대학1  이정아  목3 ,목4
#
#          강의실  정원
# 39  비전타워-418  30
# 40  비전타워-202  30
# 41  비전타워-303  30
# 42  비전타워-202  30
# 43  비전타워-303  30
# 저장 중: 비전타워_강의목록.csv
# 필터링 완료! 결과 저장: 비전타워_강의목록.csv

# %%
import pandas as pd
import warnings

warnings.simplefilter(action='always', category=UserWarning)  # 경고 메시지 출력

# 파일 로드 함수
def load_data(file_path):
    print(f"파일 로드 중: {file_path}")
    if file_path.endswith('.xlsx') or file_path.endswith('.xls'):
        df = pd.read_excel(file_path)
    elif file_path.endswith('.csv'):
        df = pd.read_csv(file_path, encoding='utf-8')
    else:
        raise ValueError("지원하지 않는 파일 형식입니다. XLSX 또는 CSV 파일을 사용하세요.")

    print("데이터 로드 완료!")
    print(df.head())
    print("데이터프레임 컬럼 목록:", df.columns)  # 컬럼 확인

    return df

# 비전타워 강의실 필터링 및 층 구별
def filter_visiontower(df):
    print("비전타워 강의실 필터링 중...")
    df['강의실'] = df['강의실'].astype(str).str.strip()  # 공백 제거
    df['강의실'] = df['강의실'].str.replace(' ', '')  # 공백 제거

    print("강의실 목록:", df['강의실'].unique())  # 강의실 목록 확인
    filtered_df = df[df['강의실'].str.contains('비전타워', na=False)]

    # 층 정보 추출 (예: '비전타워 B103' -> 'B1층')
    filtered_df['층'] = filtered_df['강의실'].str.extract(r'(B?\d)')
    filtered_df['층'] = filtered_df['층'].apply(lambda x: f"{x}층" if pd.notna(x) else "층 정보 없음")

    print(f"필터링된 강의 수: {len(filtered_df)}개")
    print(filtered_df.head())
    return filtered_df[['층', '교과목명', '강의시간', '강의실']].sort_values(by=['층', '강의실'])

# 실행 함수
def main(file_path, output_path):
    df = load_data(file_path)
    visiontower_df = filter_visiontower(df)

    if visiontower_df.empty:
        print("⚠️ 필터링 결과가 없습니다! 데이터 확인 필요.")

    print(f"저장 중: {output_path}")
    visiontower_df.to_csv(output_path, index=False, encoding='utf-8')
    print(f"필터링 완료! 결과 저장: {output_path}")

# 실행 예시
main('시간표_및_강의계획서_최종통합.xlsx', '비전타워_강의목록_층별 시간표.csv')
# Out:
# 파일 로드 중: 시간표_및_강의계획서_최종통합.xlsx
# 데이터 로드 완료!
#   No      학수번호                          교과목명 관련영상          영역  이수      학점  \
# 0  1  14736002                       일본의이해     없음  [계교]인문사회과학  계교  3(3/0)
# 1  2  15503001  한국어학의 이해 (Flipped Learning)    없음  [계교]인문사회과학  계교  3(2/1)
# 2  3  15503002  한국어학의 이해 (Flipped Learning)    없음  [계교]인문사회과학  계교  3(2/1)
# 3  4  15504001               문화콘텐츠 분석과 상상력     없음  [계교]인문사회과학  계교  3(2/1)
# 4  5  15504002               문화콘텐츠 분석과 상상력     없음  [계교]인문사회과학  계교  3(2/1)
#
#       개설조직  담당교수        강의시간      강의실  정원
# 0  AI인문대학1   이수향  수3 ,수4 ,금3  가천관-315  60
# 1  AI인문대학1  정한데로  월7 ,수5 ,수6  가천관-413  40
# 2  AI인문대학1  정한데로  월8 ,수7 ,수8  가천관-413  40
# 3  AI인문대학1   김진규  월3 ,월4 ,수4  가천관-414  40
# 4  AI인문대학1   김진규  화3 ,화4 ,수3  가천관-414  40
# 데이터프레임 컬럼 목록: Index(['No', '학수번호', '교과목명', '관련영상', '영역', '이수', '학점', '개설조직', '담당교수', '강의시간',
#        '강의실', '정원'],
#       dtype='object')
# 비전타워 강의실 필터링 중...
# 강의실 목록: ['가천관-315' '가천관-413' '가천관-414' '가천관-612' '가천관-416' '가천관-423' '가천관-419'
#  '가천관-421' '가천관-422' '화상강의강의실(가상)' '가천관-317' '가천관-403' '가천관-402' '가천관-314'
#  '글로벌센터-215' '글로벌센터-303' '글로벌센터-301' '글로벌센터-307' '글로벌센터-103' '글로벌센터-104'
#  '글로벌센터-111' '글로벌센터-112' '글로벌센터-203' '글로벌센터-204' '글로벌센터-212' '비전타워-418'
#  '비전타워-202' '비전타워-303' '바이오나노대학-210,바이오나노대학-103' '바이오나노대학-103,바이오나노대학-210'
#  '바이오나노대학-305,바이오나노대학-206' '바이오나노대학-402,바이오나노대학-101'
#  '바이오나노대학-101,바이오나노대학-402' '바이오나노대학-504,바이오나노대학-306' 'AI관-208'
#  '공과대학2-601A' '비전타워-414' '비전타워-314' '비전타워-417' '공과대학2-302' 'AI관-303'
#  'AI관-408' 'AI관-302' 'AI관-507' 'AI관-209' '비전타워-407' 'AI관-415' 'AI관-407'
#  '비전타워-412' 'AI관-412' 'AI관-413' '비전타워-423' 'AI관-508' 'AI관-510'
#  'AI관-503,AI관-210' 'AI관-503' '비전타워-310' 'AI관-100' '반도체대학-501' '반도체대학-504'
#  '반도체대학-503' '반도체대학-511' '공과대학2-314' 'AI관-206' 'AI관-716' 'AI관-305'
#  'AI관-301' 'AI관-426' '공과대학2-319' '반도체대학-403' '공과대학2-316' 'AI관-517'
#  'AI관-330' 'AI관-328' 'AI관-749' 'AI관-748' 'AI관-414' 'AI관-509' 'AI관-511'
#  'AI관-736' 'AI관-210' '비전타워-B208-D' 'AI관-409' 'nan' '글로벌센터-217' '글로벌센터-305'
#  '글로벌센터-213' '글로벌센터-302' '글로벌센터-304' '바이오나노대학-211,바이오나노대학-104'
#  '바이오나노대학-104,바이오나노대학-211' '바이오나노대학-209,비전타워-402'
#  '바이오나노대학-403,바이오나노대학-105' '비전타워-302' '비전타워-315' '비전타워-320' '비전타워-201'
#  '비전타워-316' '비전타워-317' '비전타워-309' '비전타워-B201' '비전타워-306' '비전타워-403'
#  '비전타워-503' '비전타워-308' '비전타워-502' '비전타워-416' '비전타워-324' '비전타워-204'
#  '비전타워-B202' '글로벌센터-100' '비전타워-515' '비전타워-B105' '비전타워-B204' '비전타워-307'
#  '비전타워-304' '비전타워-305' '비전타워-체육관' '가천관-B201' '공과대학2-603C' '비전타워-415'
#  '글로벌센터-607' '반도체대학-233' '글로벌센터-504' '글로벌센터-505' '글로벌센터-506' '글로벌센터-507'
#  '글로벌센터-508' '글로벌센터-511' '글로벌센터-202' '글로벌센터-501' '글로벌센터-502' '글로벌센터-503'
#  '글로벌센터-510' '비전타워-B203' '비전타워-B104' '비전타워-402' 'AI관-211' '가천관-602'
#  '가천관-513' '가천관-301' '가천관-714' '가천관-B101' '가천관-718' '가천관-702' '가천관-701'
#  '가천관-712' '가천관-601' '가천관-502' '가천관-824' '가천관-722' '가천관-721' '가천관-720'
#  '가천관-512' '가천관-501' '가천관-840' '가천관-514' '가천관-515' '가천관-619' '가천관-713'
#  '가천관-719' '바이오나노대학-105,바이오나노대학-403' '공과대학1-101' '공과대학2-103' '공과대학1-312'
#  '공과대학1-313' '공과대학1-208' '공과대학1-311' '공과대학1-411' '공과대학1-315'
#  '공과대학1-208,공과대학1-601' '공과대학1-700' '공과대학1-508B' '공과대학1-610A' '공과대학1-508C'
#  '공과대학1-316' '공과대학1-314' '비전타워-203' '공과대학1-209' '반도체대학-227' '비전타워-510'
#  '공과대학2-505' '공과대학2-504' '공과대학2-203' '공과대학2-604' '공과대학2-105' '공과대학1-115'
#  '공과대학1-117' '공과대학1-212' '공과대학1-708' '공과대학1-301' '공과대학1-302' '공과대학1-205'
#  '공과대학1-309' '공과대학1-310' '비전타워-619' '반도체대학-302' '공과대학2-401' '반도체대학-510'
#  '공과대학2-516' '바이오나노대학-206,바이오나노대학-305' '비전타워-402,바이오나노대학-209'
#  '바이오나노대학-306,바이오나노대학-504' '교육대학원-414' '바이오나노연구원-405' '반도체대학-5_18'
#  '바이오나노대학-210' '바이오나노대학-504' '예술대학2-428' '반도체대학-5_15' '예술대학1-5E'
#  '바이오나노연구원-409' '바이오나노연구원-410' '예술대학2-426' '예술대학2-423' '교육대학원-415'
#  '교육대학원-512' '바이오나노대학-505' '바이오나노대학-402' '반도체대학-5_09' '반도체대학-5_10'
#  'AI관-715' '비전타워-206' '비전타워-413' '비전타워-319' 'AI관-714A' '반도체대학-117'
#  'AI관-714' 'AI관-717' 'AI관-504' 'AI관-505' 'AI관-306' 'AI관-410' '반도체대학-301'
#  '비전타워-B208B' '반도체대학-601' '반도체대학-602' '비전타워-509' '비전타워-419' '비전타워-617'
#  '비전타워-616' '비전타워-508' '비전타워-615' '가천관-615' '가천관-519' '가천관-522' '가천관-618'
#  '가천관-616' '가천관-613' '가천관-302' '가천관-316' '교육대학원-517' '가천관-614' '교육대학원-314'
#  '교육대학원-418' '가천관-312' '가천관-313' '가천관-620' '교육대학원-513' '가천관-617'
#  '교육대학원-317' '교육대학원-412' '교육대학원-413' '가천관-520' '제3학생생활관-B204' '교육대학원-504'
#  '교육대학원-510' '예술대학2-417' '교육대학원-507' '교육대학원-501' '교육대학원-315' '예술대학2-219'
#  '예술대학2-318' '제3학생생활관-B203' '교육대학원-508' '강의실' '공과대학2-301B' '공과대학2-301A'
#  '공과대학2-306A' '비전타워-408' 'AI관-508,AI관-410' 'AI관-412,AI관-509'
#  'AI관-407,AI관-305' 'AI관-301,AI관-511' 'AI관-301,AI관-509' 'AI관-511,AI관-413'
#  'AI관-301,AI관-413' '비전타워-503,공과대학2-304B' 'AI관-307' '공과대학2-304B' '비전타워-507'
#  'AI관-509,AI관-412' 'AI관-509,AI관-511' '가천관-204' 'AI관-301,AI관-415'
#  'AI관-510,AI관-413' 'AI관-306,AI관-305' 'AI관-413,AI관-509' 'AI관-511,AI관-414'
#  'AI관-414,AI관-301' 'AI관-413,AI관-511' 'AI관-301,AI관-412' 'AI관-509,AI관-415'
#  'AI관-306,AI관-504' 'AI관-414,AI관-413' '비전타워-502,AI관-414' 'AI관-411'
#  'AI관-511,AI관-301' '가천관-619,가천관-602' '가천관-715' '공과대학2-503'
#  '공과대학2-203,공과대학2-604' '비전타워-318' '공과대학1-308' '공과대학1-106' '공과대학2-608'
#  '공과대학2-508' '공과대학2-502' '공과대학2-404' '반도체대학-220' '반도체대학-612'
#  '공과대학2-401,반도체대학-302' '공과대학1-309,공과대학1-313' '공과대학1-308,공과대학1-309'
#  '공과대학2-401,비전타워-318' '반도체대학-227,반도체대학-510' '공과대학2-604,공과대학2-203'
#  '공과대학2-507' '반도체대학-302,공과대학2-401' '공과대학2-401,반도체대학-227' '공과대학2-202'
#  '공과대학1-313,공과대학1-315' '공과대학1-313,공과대학1-311' '공과대학1-218' '공과대학1-410'
#  '공과대학1-308,공과대학1-310' '공과대학1-309,공과대학1-310' '비전타워-B103'
#  '반도체대학-510,반도체대학-227' '공과대학2-103,공과대학2-203' '공과대학2-105,공과대학2-604'
#  '공과대학2-407' '바이오나노대학-404' '바이오나노대학-505,바이오나노대학-504' '바이오나노대학-206'
#  '예술대학2-430' '바이오나노연구원-407' '바이오나노대학-208,바이오나노대학-502'
#  '바이오나노대학-502,바이오나노대학-208' '바이오나노대학-503,바이오나노대학-208'
#  '예술대학2-430,예술대학2-106A' '예술대학2-106A' '바이오나노대학-503' '예술대학2-323'
#  '바이오나노대학-401' '바이오나노대학-502' '교육대학원-218,교육대학원-415' '바이오나노연구원-408'
#  '바이오나노대학-208,바이오나노대학-503' '바이오나노대학-405' '교육대학원-218,교육대학원-512' '교육대학원-613'
#  '교육대학원-220' '교육대학원-415,교육대학원-414' '예술체육대학2-B134' '바이오나노대학-208'
#  '바이오나노대학-306' '반도체대학-233,반도체대학-117' '비전타워-619,비전타워-423'
#  '비전타워-619,비전타워-414' '반도체대학-117,AI관-410' '반도체대학-301,반도체대학-117' '반도체대학-305'
#  '반도체대학-301,반도체대학-601' '반도체대학-601,반도체대학-301' 'AI관-505,AI관-410'
#  '반도체대학-601,비전타워-206' '대학원-301호' '비전타워-702B' '비전타워-702C' '가천관-514,가천관-512'
#  '가천관-415' '교육대학원-108' '가천관-313,가천관-302' '교육대학원-516' '가천관-415,가천관-512'
#  '교육대학원-209,교육대학원-518' '교육대학원-209' '교육대학원-420' '가천관-615,가천관-620'
#  '교육대학원-517,교육대학원-504' '가천관-702,가천관-617' '교육대학원-318' '교육대학원-312'
#  '교육대학원-319' 'AI관-607' '가천관-420' '예술대학1-101' '바이오나노대학-304' '예술대학1-106B'
#  '예술대학1-106C' '예술대학1-402' '예술대학1-307' '예술대학2-403' '예술대학2-406' '예술대학2-405'
#  '예술대학2-407' '예술대학2-311' '예술대학2-313' '예술대학2-203' '예술대학2-215' '예술대학2-205'
#  '예술대학2-209' '예술대학2-214' '예술대학2-206' '예술대학2-208' '예술대학2-202' '예술대학2-220A'
#  '예술대학2-119B' '예술대학2-218' '예술대학2-301' '예술대학2-310' '예술대학2-413' '예술대학2-414'
#  '예술대학2-412' '예술대학2-221C' '예술대학2-404' '예술대학2-204' '예술대학2-221B' '예술대학2-312'
#  '예술대학2-303' '예술대학1-506B' '예술대학1-406B' '예술대학1-508A' '예술대학1-506A'
#  '예술대학1-507' '예술대학1-604' '예술대학1-602B' '예술대학1-702' '예술대학1-405' '예술대학1-404'
#  '교육대학원-103' '예술대학1-201' '예술대학2-302' '예술대학2-401' '예술대학2-402' '예술대학2-304'
#  '예술대학2-306' '예술대학2-100' '예술대학2-216' '예술대학2-316' '예술대학2-420' '테니스장'
#  '교육대학원-628' '예술대학2-409' '바이오나노연구원-200' '비전타워-B154' '교육대학원-501,교육대학원-507'
#  '예술대학1-501' '예술대학1-202' '예술대학1-204B' '교육대학원-507,교육대학원-501' '예술대학1-104'
#  '예술대학2-307' '예술대학1-701' '예술대학1-603' '예술대학1-306' '제3학생생활관-B201'
#  '비전타워-B157,비전타워-B155,바이오나노연구원-200' '비전타워-B155' '비전타워-B155,비전타워-B157'
#  '제3학생생활관-B118' '교육대학원-103,제3학생생활관-B118' '제3학생생활관-B203,제3학생생활관-B201'
#  '예술대학1-305A' '가천관-401' '가천관-403,가천관-413']
# 필터링된 강의 수: 580개
#     No      학수번호       교과목명 관련영상        영역  이수      학점     개설조직 담당교수    강의시간  \
# 39  40  13549014  인문사회글쓰기     없음  [기초]의사소통  교필  2(2/0)  AI인문대학1  허재홍  목5 ,목6
# 40  41  13549041  인문사회글쓰기     없음  [기초]의사소통  교필  2(2/0)  AI인문대학1  변정민  목5 ,목6
# 41  42  13549042  인문사회글쓰기     없음  [기초]의사소통  교필  2(2/0)  AI인문대학1  최정혜  목5 ,목6
# 42  43  13549043  인문사회글쓰기     없음  [기초]의사소통  교필  2(2/0)  AI인문대학1  정우진  목3 ,목4
# 43  44  13549044  인문사회글쓰기     없음  [기초]의사소통  교필  2(2/0)  AI인문대학1  이정아  목3 ,목4
#
#          강의실  정원   층
# 39  비전타워-418  30  4층
# 40  비전타워-202  30  2층
# 41  비전타워-303  30  3층
# 42  비전타워-202  30  2층
# 43  비전타워-303  30  3층
# 저장 중: 비전타워_강의목록_층별 시간표.csv
# 필터링 완료! 결과 저장: 비전타워_강의목록_층별 시간표.csv
# <ipython-input-12-8cb7f7f053e7>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['층'] = filtered_df['강의실'].str.extract(r'(B?\d)')
# <ipython-input-12-8cb7f7f053e7>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['층'] = filtered_df['층'].apply(lambda x: f"{x}층" if pd.notna(x) else "층 정보 없음")
